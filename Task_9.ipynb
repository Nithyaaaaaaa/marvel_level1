# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np
import os
import warnings

from joblib import load
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.exceptions import InconsistentVersionWarning

# %% [markdown]
# This section imports all the necessary Python libraries required for the task.
#
# - **panda** is used for loading and manipulating datasets in tabular format.
# - **numpy** is used for numerical operations.
# - **os** helps interact with the operating system, especially for file and directory handling.
# - **warnings** is used to manage and suppress non-critical warnings for cleaner output.
#
# - **joblib** is specifically used to load pretrained machine learning models saved as `.pkl` files.
# - **LabelEncoder** is used to convert categorical class labels into numerical form.
# - **sklearn.metrics** provides standard evaluation metrics such as accuracy, precision, recall, and F1-score.
# - **InconsistentVersionWarning** is imported to suppress warnings caused by scikit-learn version mismatch.

# %% [markdown]
# ## Suppress Library Version Warnings

# %%
warnings.filterwarnings("ignore", category=InconsistentVersionWarning)

# %% [markdown]
# The pretrained models were saved using an older version of scikit-learn, while the current
# environment uses a newer version. This can generate warning messages during model loading.
#
# Since the task only involves prediction and evaluation (not retraining),
# these warnings do not affect correctness. Suppressing them helps keep the notebook output clean.

# %% [markdown]
# ## Load the Test Dataset

# %%
df_test = pd.read_csv("iris.csv")
df_test.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# Here, the test dataset is loaded from a CSV file into a Pandas DataFrame.
# Displaying the first few rows helps confirm that the dataset has been loaded correctly
# and provides an overview of the input features and the target variable.

# %% [markdown]
# ## Separating Features and Target Variable

# %%
X_test = df_test.drop(["Id", "Species"], axis=1)
y_test = df_test["Species"]

# %% [markdown]
# At this stage, the dataset is divided into input features and the target variable.
# The identifier column is removed since it does not contribute to prediction,
# and the target column is isolated so that model predictions can be compared
# against the true class labels during evaluation.

# %% [markdown]
# ## Encoding the Target Labels

# %%
le = LabelEncoder()
y_test_encoded = le.fit_transform(y_test)

print("Encoded classes:", le.classes_)
# Out:
# Encoded classes: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [markdown]
# Since some pretrained models were trained using numerical class labels,
# the target variable is encoded into numeric form.
# This ensures that the true labels and the predicted labels are in the same format,
# which is necessary for correctly calculating evaluation metrics.

# %% [markdown]
# ## Locating Pretrained Model Files

# %%
os.listdir("/Users/nithyashreevsuresh/Downloads")
# Out:
# ['Java_3 (2).pptx',
#  'Java_2 (2).pptx',
#  'JetBrainsAcademy',
#  'marvel report.docx',
#  'noise_removed_noise_removed_ese-20250920182529-1708827-42524-result.mp3',
#  'CoMUN.docx',
#  '262755467_2011403169022591_1125140996844298508_n.jpg',
#  '244721527_411633560572866_4763931205448277784_n.jpg',
#  'housing.csv',
#  'Visual Studio Code.app',
#  'DSD Assign.pdf',
#  'uucms.karnataka.gov.in_ExamGeneral_StudentPrintExamApplication.pdf',
#  'WhatsApp Image 2025-12-16 at 8.09.10 PM (2).jpeg',
#  '261572338_208525181452786_4644280492538246708_n.jpg',
#  'merged_37054ec5-afe8-4095-83b9-8badc0a92caa.pptx',
#  'codefury handle white-01 (1).png',
#  'model5_random_forest (1).pkl',
#  'model2_logistic_regression (1).pkl',
#  'Nithyashree V Suresh CodeFury 8.0 Participants Certificate.pdf',
#  '244647376_234539405386591_5024659469483479435_n.jpg',
#  'Translated Presentation (Hindi).pdf',
#  'Movies.ipynb',
#  '244469469_393441042496156_3130718381813033869_n.webp',
#  'ppt for parliamentary committe -women welfare.pdf',
#  'housing.csv.zip',
#  'images-removebg-preview.png',
#  'fictional_movies.csv',
#  '262555421_4417205845055191_964110606577573826_n.jpg',
#  '267516450_186075593738962_790845634596670373_n.jpg',
#  'open-weather-master',
#  '7d6aba1f-bcf3-4d87-9bfd-8a5847e1801a_merged.pptx',
#  'WhatsApp Image 2025-10-29 at 7.21.04 PM.jpeg',
#  'Timeline 1.mp4',
#  'Fourier transforms.pdf',
#  'Copy-of-UNIVERSITY-OF-VISVESVARAYA-COLLEGE-OF-ENGINEERING (1).pptx',
#  'MarvelTask20.ipynb',
#  '241422590_2133323500148847_1773085827582950198_n.jpg',
#  '8 (2).ipynb',
#  'ReportLevel0.ipynb',
#  'Task 12_ Soldering Prerequisites.html',
#  '1st Unit- i) Fourier Series (4).pdf',
#  'Adobe Scan 03 Aug 2025.pdf',
#  '246005317_208273661404567_8016716043624611565_n.jpg',
#  'b032833c04ce4cf989301edaaeabb2ea.pdf',
#  'fictional_movies (1).csv',
#  '258337051_430076328706484_6787025091155306688_n.jpg',
#  'JAVA_INTRO.pptx',
#  '263049940_658359158660413_1300808956254943958_n.jpg',
#  'model4_svm (1).pkl',
#  '254475911_1034335213775262_1767878942913753601_n.jpg',
#  '1st Unit- i) Fourier Series (5).pdf',
#  'ieee black logo-01.png',
#  '.DS_Store',
#  'Fourier transforms (1).pdf',
#  'java_2.1 (1).pptx',
#  '1000118283.pdf',
#  'images.jpeg',
#  '256218496_609851517100040_7529575585531105974_n.jpg',
#  'Nithya_report (2).docx',
#  'model4_svm.pkl',
#  'CPRI_Women_Welfare_Hindi_Translated (1).pdf',
#  'jumper_3',
#  'Video.mov',
#  'Machine Learning.ipynb',
#  'thank-you-words-on-notepad-and-office-supplies-free-photo.jpg',
#  'Untitled6 (2).ipynb',
#  '8.ipynb',
#  'Snuffles_Keychain.stl',
#  'customer_data - customer_data.csv',
#  'customer_data (1).csv',
#  'java_3.2.pptx',
#  'Sponsorship Updates - Google Sheets.html',
#  'JAVA_INTRO (1).pptx',
#  'UVCE_BTech_Microsoft_SEFA.pdf',
#  '263462963_1573013629750829_434243163519888239_n (2).jpg',
#  'Task3Fairlight.mov',
#  '.localized',
#  'Report 2.pages',
#  'LinearRegressionFromScratch.ipynb',
#  'iZotope RX 11 Audio Editor Advanced v11.2.0 U2B macOS [FileCR].zip',
#  'WhatsApp Image 2025-12-16 at 8.09.10 PM.jpeg',
#  'Timeline 1.mov',
#  'anomaly_detection.csv',
#  'WhatsApp Image 2025-12-16 at 8.09.10 PM (1).jpeg',
#  'UNIVERSITY-OF-VISVESVARAYA-COLLEGE-OF-ENGINEERING.pdf',
#  'matrix_task6.ipynb',
#  'Untitled.ipynb',
#  'imail ids utilities.docx',
#  'Fuji_FLog_Grading_Template.drx',
#  '250035733_444612510334967_7792624022210561316_n.jpg',
#  'Machine Learning (2).ipynb',
#  'Nithyashree V Suresh CodeFury 8.0 Participants Certificate_page-0001.jpg',
#  'Java_3.pptx',
#  '245829985_556247722143104_4225184542238876624_n.jpg',
#  'task_5.ipynb',
#  'Assignment 3.mp4',
#  'task8 (2).ipynb',
#  'images-removebg-preview (1).png',
#  'Java_3 (1).pptx',
#  '1st Unit- i) Fourier Series (2).pdf',
#  '225483277_908604476390912_1856370950122327659_n.jpg',
#  'Java_2 (1).pptx',
#  'Untitled4.ipynb',
#  'UHV III SEM 2025.pdf',
#  '263156785_434118848248554_7242450008079010855_n.jpg',
#  'Sponsorship Updates',
#  'Report 3.doc',
#  'marldown_task.ipynb',
#  'Untitled6.ipynb',
#  'Fictional Movies.ipynb',
#  'Report_task_1&2.ipynb',
#  'organized.pdf',
#  'Report on Machine Learning Concepts.html',
#  'Syllabus+for+100+Days+of+Python.pdf',
#  'WhatsApp Image 2025-12-16 at 8.09.09 PM.jpeg',
#  'noise_removed_ese-20250920182529-1708827-42524-result.mp3',
#  'Report.docx',
#  'Copy-of-UNIVERSITY-OF-VISVESVARAYA-COLLEGE-OF-ENGINEERING.pptx',
#  'java_2.1.pptx',
#  'marketplace-100_Days_of_Code_-_The_Complete_Python_Pro_Bootcamp-9',
#  'open-weather-master.zip',
#  'Report 2.doc',
#  'linear regression.ipynb',
#  '246391897_619006205912543_2045929462601570196_n.jpg',
#  '266848413_5239164592779818_6976268886512655907_n.jpg',
#  'iZotope RX 11 Audio Editor Advanced v11.2.0 U2B macOS',
#  '212095018_658085072249535_5270041632875204970_n.jpg',
#  'Sponsorship Updates.xlsx',
#  'level 1 _ task 1,2.md',
#  'Nithya_report (1).docx',
#  'git-task-main.zip',
#  'book.svg',
#  'jumper_3.zip',
#  'Noto-Serif-Medium',
#  'noise_removed_noise_removed_ese_20250920182529_1708827_42524_result_clean.mp3',
#  'WhatsApp Image 2025-09-25 at 10.16.25 PM.jpeg',
#  'Nikhil_SI_1.pptx',
#  '241725123_184603223780811_7471356317035128779_n.jpg',
#  'WhatsApp Image 2025-12-16 at 8.09.08 PM.jpeg',
#  'Unit Ib Pointers and DMA Unit.pdf',
#  'marketplace-100_Days_of_Code_-_The_Complete_Python_Pro_Bootcamp-9-2',
#  'drive-download-20250919T150343Z-1-001',
#  'encoded_array (1).npy',
#  'Noto_Serif.zip',
#  '245708133_932999493982743_3814218876617969933_n.jpg',
#  'model5_random_forest.pkl',
#  'java_2.1 (2).pptx',
#  '268607033_1050264625820245_228333591051566540_n.jpg',
#  '1st Unit- ii) Complex Fourier Series & Harmonics.pdf',
#  '270199339_734695827508060_1944115344345418569_n.jpg',
#  'Inter,Noto_Serif (1).zip',
#  '01 Introduction to Data Structures.pdf',
#  'IMG_3989.JPG',
#  '270219507_1596601740705534_3576635838838865279_n.jpg',
#  '1st Unit- i) Fourier Series.pdf',
#  '1st Unit- i) Fourier Series (3).pdf',
#  'KAGADA Partnership Brochure.pdf',
#  'Sponsorship Updates.zip',
#  'node-v22.18.0.pkg',
#  '245185954_638496534198433_5395093777983024128_n.jpg',
#  'Inter,Noto_Serif (2)',
#  'Copy of Resume.pdf',
#  '239462022_253510793263572_8124882361184222616_n.jpg',
#  'Unit 2a stacks.pdf',
#  'Java_2.pptx',
#  'customer_data.csv',
#  'WhatsApp Image 2025-12-16 at 8.09.09 PM (1).jpeg',
#  'JAVA_INTRO (2).pptx',
#  'DSA NOTES till linked list (1).pdf',
#  'git-task-main',
#  'data.csv',
#  'Movies (1).ipynb',
#  '3rd sem fourier series (1).pdf',
#  'Report 4.doc',
#  '8 (3).ipynb',
#  'Inter,Noto_Serif (2).zip',
#  '242215771_546443889982636_129221352353875125_n.jpg',
#  '267761614_239426774970843_3914537763195988470_n.jpg',
#  'LH Permission letter - Google Docs.pdf',
#  'python-3.13.5-macos11.pkg',
#  'Report 2.pdf',
#  'uhv shubha.pdf',
#  'CPRI_Women_Welfare_Hindi_Translated.pdf',
#  'drive-download-20250818T090247Z-1-001',
#  'Marvel_Task_4.ipynb',
#  'Nithya_report.pages',
#  'WhatsApp Image 2025-12-16 at 8.09.08 PM (2).jpeg',
#  'VID-20250722-WA0013.mp4',
#  '_OceanofDMG.com_iZotope_RX_9_Audio_Editor_Advanced_v9.3.0.rar',
#  'CPRI_Women_Welfare_Hindi_Translated (4).pdf',
#  'Unit Ia Introduction DS and  Structures.pdf',
#  'template - Summer internship report (1).docx',
#  '263219534_3111758195727980_3805712745203443847_n.jpg',
#  '271312836_2795087787456066_2572639197193062977_n.jpg',
#  '245099489_392971255753917_163006791818844139_n.jpg',
#  '3rd sem fourier series (2).pdf',
#  'UHV III SEM 2025 (1).docx',
#  'codefury handle white-01.png',
#  '249385872_603257934044371_2516331694049801782_n.jpg',
#  'SmartSwitch4Mac_setup.dmg',
#  '240475681_377505813744746_112525992513521300_n.jpg',
#  'java_2.3.pptx',
#  'Iris.csv',
#  'Unknown-2',
#  'model1_decision_tree.pkl',
#  '241126499_1467999913579456_316731006613851164_n.jpg',
#  'merged_presentation_choladeck.pptx',
#  'OOPs LAB MANUAL.pdf',
#  'UNIVERSITY-OF-VISVESVARAYA-COLLEGE-OF-ENGINEERING (1).pptx',
#  'task_20.ipynb',
#  '2025-09-23 19-17-02.pdf',
#  'COAChap1 (1) (2).ppt',
#  'Slide1_Hindi_Demo.pdf',
#  'Marvel_Task_4 (1).ipynb',
#  'pleasee.docx',
#  'Task8report.ipynb',
#  'framingham.csv',
#  'Untitled6 (1).ipynb',
#  '251866122_598300221321556_3373294433072715658_n.jpg',
#  'logo.png',
#  'MarvelL1T4.ipynb',
#  '241903661_1015223125940916_4724341609648277472_n.jpg',
#  'IEEE UVCE White.png',
#  '217734182_350128523458414_851940477911142762_n.jpg',
#  'task8.ipynb',
#  'SUMMER INTERNSHIP (3).pptx',
#  'Arjun 5th sem internship.docx.pdf',
#  'Arjun 5th sem internship.docx',
#  'Unit 2c Queues.pdf',
#  'UNIVERSITY-OF-VISVESVARAYA-COLLEGE-OF-ENGINEERING.zip',
#  'Video from Nithya_).mp4',
#  'OOPs with C++ Laboratory manual.pdf',
#  'Nikhil_SI_1.pdf',
#  'java_2.2.pptx',
#  'encoded_array.npy',
#  'book (1).svg',
#  'Noto_Serif (1)',
#  'detective',
#  'Skills-Acquired (2).pptx',
#  '254773122_699140697726246_2457776689199000733_n.jpg',
#  'CPRI_Women_Welfare_Hindi_Translated (5).pdf',
#  'Task_9.ipynb',
#  '244792640_538114200567102_3796990676945525892_n.jpg',
#  'iZotope_RX_11_Audio_Editor_Advanced_v11_3_0.dmg',
#  '8 (1).ipynb',
#  'portfolio',
#  '262916970_4567335599999134_6104215329726303935_n.jpg',
#  '3rd sem fourier series.pdf',
#  '1st Unit- i) Fourier Series (1).pdf',
#  'DSA LAB MANUAL.pdf',
#  'Nikhil_SI_1 (2).pptx',
#  'template - Summer internship report.docx',
#  'Inter,Noto_Serif.zip',
#  'model1_decision_tree (1).pkl',
#  'WhatsApp Image 2025-12-16 at 8.09.08 PM (1).jpeg',
#  '.ipynb_checkpoints',
#  'Data Visualization in AI & Analytics.md',
#  'UNIVERSITY-OF-VISVESVARAYA-COLLEGE-OF-ENGINEERING.pptx',
#  'model3_knn (1).pkl',
#  'math.ipynb',
#  'java_3.1.pptx',
#  'drive-download-20250809T134833Z-1-001',
#  '263462963_1573013629750829_434243163519888239_n (1).jpg',
#  'model2_logistic_regression.pkl',
#  'CPRI_Slide1_Hindi_Demo_FIXED.pdf',
#  'Fujifilm XT3 4k 50p h265 10bit F-log daylight.mov',
#  'model3_knn.pkl',
#  'MatrixPuzzleTask6.ipynb',
#  'Task 12_ Soldering Prerequisites.md',
#  'Unknown',
#  '264213695_487230949450184_5266825491288776779_n.jpg',
#  'task8 (3).ipynb',
#  'MarvelL1T4 (1).ipynb',
#  'Movies (2).ipynb',
#  '35f334d6-2380-446b-8b4f-e5324f7c1c66.docx',
#  '1st Unit- i) Fourier Series (6).pdf',
#  'CPRI_Slide1_Hindi_Demo.pdf',
#  'LEVEL 0&1 AIML Syllabus.pdf',
#  '241487234_906082130324464_60233739095716993_n.jpg',
#  'Untitled (1).ipynb',
#  'organized.docx',
#  'pycharm-community-2025.1.3.1-aarch64.dmg',
#  'CPRI_Women_Welfare_Hindi_Translated (2).pdf',
#  'Noto-Serif-Medium.zip',
#  '245207885_621050979073756_5091966561082601417_n.jpg',
#  '255009890_1915249345313758_1134150055987931723_n.jpg',
#  '271373382_633649667879053_6366851507631891354_n.jpg',
#  '2nd year Syllabus.pdf',
#  'Screenshot_25-12-2025_185521_www.instagram.com.jpeg',
#  '217540763_216952066847463_1454145102377376094_n.jpg',
#  'Data Visualization in AI & Analytics.html',
#  'Noto_Serif (1).zip',
#  'Nithya_resume.pdf',
#  'videoplayback.mp4',
#  'UHV III SEM 2025.docx',
#  'DOC-20250111-WA0017..PDF',
#  'CPRI_Women_Welfare_Hindi_Translated (3).pdf',
#  'Object-Oriented-Programming-text-book-4.pdf',
#  'task8 (1).ipynb',
#  '261315844_3028433670748005_4544669166071889707_n.jpg',
#  'Nithya_report.docx',
#  'Task8_report.ipynb',
#  'data.numbers',
#  'Machine Learning (1).ipynb',
#  'drive-download-20250811T124350Z-1-001',
#  '1st Unit- i) Fourier Series (7).pdf',
#  '244443206_618511939530547_785608309776455480_n.webp',
#  'DocScanner 13 Nov 2025 5-34\u202fpm.pdf',
#  'MarvelL1T3.ipynb',
#  '248826576_559512445154418_6318647173840086263_n.jpg',
#  '263462963_1573013629750829_434243163519888239_n.jpg',
#  'Machine Design - 2 Assignment - II.pdf',
#  'ese-20250920182529-1708827-42524-result.mp3',
#  'pdf2doc.zip',
#  '1.png',
#  '238870215_886513775276539_5962687423907776207_n.jpg',
#  'VSCode-darwin-universal.zip',
#  'Skills-Acquired.pptx',
#  '242664534_333797141854733_8798488674219830059_n.jpg',
#  'HMT BALAJI. S.pdf',
#  'Nikhil_SI_1 (1).pptx',
#  'ReportLevel0-2.ipynb',
#  'Skills-Acquired (1).pptx',
#  '244455124_895050844729230_3292401300075238710_n.webp',
#  '257434205_993914928138400_3916429426290117710_n.jpg',
#  'MarvelTask20 (1).ipynb',
#  'Unit 2b recursion.pdf',
#  'SpiderKeyBig.stl',
#  'Screenshot-2020-09-18-at-9.35.13-AM.png']

# %% [markdown]
# Before loading the pretrained models, the directory containing the model files
# is checked to ensure that all required `.pkl` files are present.
# This step helps avoid file-not-found errors during model loading.

# %% [markdown]
# ## Loading Pretrained Models

# %%
model_files = [
    "model1_decision_tree.pkl",
    "model2_logistic_regression.pkl",
    "model3_knn.pkl",
    "model4_svm.pkl",
    "model5_random_forest.pkl"
]

models = {}

for file in model_files:
    try:
        models[file] = load(f"/Users/nithyashreevsuresh/Downloads/{file}")
        print(f"{file} loaded successfully")
    except Exception as e:
        print(f"{file} failed to load:", e)
# Out:
# model1_decision_tree.pkl loaded successfully
# model2_logistic_regression.pkl loaded successfully
# model3_knn.pkl loaded successfully
# model4_svm.pkl loaded successfully
# model5_random_forest.pkl loaded successfully

# %% [markdown]
# In this step, the pretrained machine learning models are loaded using joblib.
# These models have already been trained earlier and are directly used for prediction.
# Loading them into a dictionary makes it easy to evaluate all models using the same test data.

# %% [markdown]
# ## Verifying Loaded Models

# %%
models.keys()
# Out:
# dict_keys(['model1_decision_tree.pkl', 'model2_logistic_regression.pkl', 'model3_knn.pkl', 'model4_svm.pkl', 'model5_random_forest.pkl'])

# %% [markdown]
# After loading the models, this step confirms that all models were successfully loaded.
# Verifying this ensures that the evaluation process includes all models
# and that no model is accidentally skipped.

# %% [markdown]
# ## Evaluating the Models

# %%
results = []

for name, model in models.items():
    y_pred = model.predict(X_test)

    results.append({
        "Model": name,
        "Accuracy": accuracy_score(y_test_encoded, y_pred),
        "Precision": precision_score(y_test_encoded, y_pred, average="weighted"),
        "Recall": recall_score(y_test_encoded, y_pred, average="weighted"),
        "F1": f1_score(y_test_encoded, y_pred, average="weighted")
    })
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SVC was fitted without feature names
#   warnings.warn(
# /opt/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %% [markdown]
# Here, each pretrained model is used to make predictions on the test dataset.
# The predicted labels are then compared with the true labels using evaluation metrics
# such as accuracy, precision, recall, and F1-score.
# These metrics help quantify how well each model performs.

# %% [markdown]
# ## Displaying Evaluation Results

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#                             Model  Accuracy  Precision    Recall        F1
# 0        model1_decision_tree.pkl  0.953333   0.956229  0.953333  0.953216
# 1  model2_logistic_regression.pkl  0.973333   0.973825  0.973333  0.973323
# 2                  model3_knn.pkl  0.966667   0.967751  0.966667  0.966637
# 3                  model4_svm.pkl  0.973333   0.973825  0.973333  0.973323
# 4        model5_random_forest.pkl  0.966667   0.966787  0.966667  0.966663

# %% [markdown]
# The evaluation results of all models are displayed in a tabular format.
# This makes it easier to compare the performance of different models
# and identify which model performs better across various metrics.

# %% [markdown]
# ## Selecting the Best Model

# %%
best_model = results_df.sort_values(
    by="F1", ascending=False
).iloc[0]

best_model
# Out:
# Model        model2_logistic_regression.pkl
# Accuracy                           0.973333
# Precision                          0.973825
# Recall                             0.973333
# F1                                 0.973323
# Name: 1, dtype: object

# %% [markdown]
# In this step, the best-performing model is selected based on the highest F1-score.
# F1-score is chosen because it provides a balanced measure of precision and recall,
# making it suitable for comparing classification models.

# %%
results_df.to_csv("model_comparison_results.csv", index=False)
